# %%
## sigmoid function with math.exp

# %%
import math

# %%
def basic_sigmoid(x):
    """
    compute sigmoid of x.

    :param
    x -- A scalar

    :return
    s -- sigmoid(x)
    """

    s = 1/(1+math.exp(-x))
    return s
